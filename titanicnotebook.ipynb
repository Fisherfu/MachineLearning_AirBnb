# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

from sklearn import preprocessing 
from sklearn.model_selection import GridSearchCV 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import RandomForestRegressor



import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

pd.options.mode.chained_assignment = None


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
train_data = pd.read_csv("/kaggle/input/titanicdataset/train.csv")
test_data = pd.read_csv("/kaggle/input/titanicdataset/test.csv")
submit = pd.read_csv('/kaggle/input/gender-submission/gender_submission.csv')
#test_data = pd.read_csv("/kaggle/input/titanicdataset/test.csv")
### show the columns of data
train_data.head(5)
# Out:
# /kaggle/input/titanicdataset/train.csv
# /kaggle/input/titanicdataset/test.csv
# /kaggle/input/gender-submission/gender_submission.csv
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## check the null values

train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
## check the null values

test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
## describe data's descriptive statistics
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
## describe data's descriptive statistics
test_data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
# Combine train and test data 
data = pd.concat([train_data, test_data], ignore_index=True)

data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %%
data.reset_index(inplace=True, drop=True)

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked
# 0         0           A/5 21171    7.2500   NaN        S
# 1         0            PC 17599   71.2833   C85        C
# 2         0    STON/O2. 3101282    7.9250   NaN        S
# 3         0              113803   53.1000  C123        S
# 4         0              373450    8.0500   NaN        S
# ...     ...                 ...       ...   ...      ...
# 1304      0           A.5. 3236    8.0500   NaN        S
# 1305      0            PC 17758  108.9000  C105        C
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307      0              359309    8.0500   NaN        S
# 1308      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#sns.countplot(data['Survived'], data=data)
sns.countplot(x='Survived', data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
data

import matplotlib.pyplot as plt

sns.countplot(x='Pclass', hue='Survived', data=data)

#sns.countplot(data['Pclass'], hue=data['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Sex', hue='Survived', data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Embarked', hue='Survived', data=data)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
g = sns.FacetGrid(data, col='Survived')
#g = sns.FacetGrid(data, col='Survived')

g.map(sns.histplot, 'Age', kde=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.histplot, 'Fare', kde=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.histplot, 'Parch', kde=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.histplot, 'SibSp', kde=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data['Family_Size'] = data['Parch'] + data['SibSp']

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.histplot, 'Family_Size', kde=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data['Title1'] = data['Name'].str.split(", ", expand=True)[1]
data['Title1'].head(3)
# Out:
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# Name: Title1, dtype: object

# %%
data['Name'].str.split(", ", expand=True).head(3)
# Out:
#            0                                           1
# 0     Braund                             Mr. Owen Harris
# 1    Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2  Heikkinen                                 Miss. Laina

# %%
data['Title1'] = data['Title1'].str.split(".", expand=True)[0]
data['Title1'].head(3)
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# Name: Title1, dtype: object

# %%
data['Title1'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer', 'Dona'], dtype=object)

# %%
pd.crosstab(data['Title1'],data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_cf9c7_row0_col0, #T_cf9c7_row0_col1, #T_cf9c7_row0_col2, #T_cf9c7_row0_col4, #T_cf9c7_row0_col5, #T_cf9c7_row0_col7, #T_cf9c7_row0_col8, #T_cf9c7_row0_col12, #T_cf9c7_row0_col15, #T_cf9c7_row0_col16, #T_cf9c7_row1_col3, #T_cf9c7_row1_col6, #T_cf9c7_row1_col9, #T_cf9c7_row1_col10, #T_cf9c7_row1_col11, #T_cf9c7_row1_col13, #T_cf9c7_row1_col14, #T_cf9c7_row1_col17 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_cf9c7_row0_col3, #T_cf9c7_row0_col6, #T_cf9c7_row0_col9, #T_cf9c7_row0_col10, #T_cf9c7_row0_col11, #T_cf9c7_row0_col13, #T_cf9c7_row0_col14, #T_cf9c7_row0_col17, #T_cf9c7_row1_col0, #T_cf9c7_row1_col1, #T_cf9c7_row1_col2, #T_cf9c7_row1_col4, #T_cf9c7_row1_col5, #T_cf9c7_row1_col7, #T_cf9c7_row1_col8, #T_cf9c7_row1_col12, #T_cf9c7_row1_col15, #T_cf9c7_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf9c7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title1</th>
#       <th id="T_cf9c7_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_cf9c7_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_cf9c7_level0_col2" class="col_heading level0 col2" >Don</th>
#       <th id="T_cf9c7_level0_col3" class="col_heading level0 col3" >Dona</th>
#       <th id="T_cf9c7_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_cf9c7_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_cf9c7_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_cf9c7_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_cf9c7_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_cf9c7_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_cf9c7_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_cf9c7_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_cf9c7_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_cf9c7_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_cf9c7_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_cf9c7_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_cf9c7_level0_col16" class="col_heading level0 col16" >Sir</th>
#       <th id="T_cf9c7_level0_col17" class="col_heading level0 col17" >the Countess</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf9c7_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_cf9c7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_cf9c7_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_cf9c7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_cf9c7_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_cf9c7_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_cf9c7_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_cf9c7_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_cf9c7_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_cf9c7_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_cf9c7_row0_col9" class="data row0 col9" >260</td>
#       <td id="T_cf9c7_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_cf9c7_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_cf9c7_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_cf9c7_row0_col13" class="data row0 col13" >197</td>
#       <td id="T_cf9c7_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_cf9c7_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_cf9c7_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_cf9c7_row0_col17" class="data row0 col17" >1</td>
#     </tr>
#     <tr>
#       <th id="T_cf9c7_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_cf9c7_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_cf9c7_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_cf9c7_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_cf9c7_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_cf9c7_row1_col4" class="data row1 col4" >7</td>
#       <td id="T_cf9c7_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_cf9c7_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_cf9c7_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_cf9c7_row1_col8" class="data row1 col8" >61</td>
#       <td id="T_cf9c7_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_cf9c7_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_cf9c7_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_cf9c7_row1_col12" class="data row1 col12" >757</td>
#       <td id="T_cf9c7_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_cf9c7_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_cf9c7_row1_col15" class="data row1 col15" >8</td>
#       <td id="T_cf9c7_row1_col16" class="data row1 col16" >1</td>
#       <td id="T_cf9c7_row1_col17" class="data row1 col17" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.groupby(['Title1'])['Age'].mean()
# Out:
# Title1
# Capt            70.000000
# Col             54.000000
# Don             40.000000
# Dona            39.000000
# Dr              43.571429
# Jonkheer        38.000000
# Lady            48.000000
# Major           48.500000
# Master           5.482642
# Miss            21.774238
# Mlle            24.000000
# Mme             24.000000
# Mr              32.252151
# Mrs             36.994118
# Ms              28.000000
# Rev             41.250000
# Sir             49.000000
# the Countess    33.000000
# Name: Age, dtype: float64

# %%
data.groupby(['Title1','Pclass'])['Age'].mean()
# Out:
# Title1        Pclass
# Capt          1         70.000000
# Col           1         54.000000
# Don           1         40.000000
# Dona          1         39.000000
# Dr            1         45.600000
#               2         38.500000
# Jonkheer      1         38.000000
# Lady          1         48.000000
# Major         1         48.500000
# Master        1          6.984000
#               2          2.757273
#               3          6.090000
# Miss          1         30.338983
#               2         20.717083
#               3         17.360874
# Mlle          1         24.000000
# Mme           1         24.000000
# Mr            1         41.450758
#               2         32.346715
#               3         28.318910
# Mrs           1         43.208955
#               2         33.518519
#               3         32.326531
# Ms            2         28.000000
#               3               NaN
# Rev           2         41.250000
# Sir           1         49.000000
# the Countess  1         33.000000
# Name: Age, dtype: float64

# %%
data['Title2'] = data['Title1'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','the Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],
         ['Miss','Mrs','Miss','Mr','Mr','Mrs','Mrs','Mr','Mr','Mr','Mr','Mr','Mr','Mrs'])

data['Title2'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
data.groupby('Title2')['Age'].mean()
# Out:
# Title2
# Master     5.482642
# Miss      21.824366
# Mr        32.811056
# Mrs       36.971264
# Name: Age, dtype: float64

# %%
data.groupby(['Title2','Pclass'])['Age'].mean()
# Out:
# Title2  Pclass
# Master  1          6.984000
#         2          2.757273
#         3          6.090000
# Miss    1         30.131148
#         2         20.865714
#         3         17.360874
# Mr      1         42.241497
#         2         32.914966
#         3         28.318910
# Mrs     1         42.802817
#         2         33.518519
#         3         32.326531
# Name: Age, dtype: float64

# %%
pd.crosstab(data['Title2'],data['Sex']).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style type="text/css">
# #T_bf05a_row0_col0, #T_bf05a_row0_col2, #T_bf05a_row1_col1, #T_bf05a_row1_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_bf05a_row0_col1, #T_bf05a_row0_col3, #T_bf05a_row1_col0, #T_bf05a_row1_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bf05a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title2</th>
#       <th id="T_bf05a_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_bf05a_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_bf05a_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_bf05a_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf05a_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_bf05a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_bf05a_row0_col1" class="data row0 col1" >264</td>
#       <td id="T_bf05a_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_bf05a_row0_col3" class="data row0 col3" >201</td>
#     </tr>
#     <tr>
#       <th id="T_bf05a_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_bf05a_row1_col0" class="data row1 col0" >61</td>
#       <td id="T_bf05a_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_bf05a_row1_col2" class="data row1 col2" >782</td>
#       <td id="T_bf05a_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(data['Title2'],data['Survived']).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style type="text/css">
# #T_1c5b3_row0_col0, #T_1c5b3_row0_col1, #T_1c5b3_row0_col3, #T_1c5b3_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1c5b3_row0_col2, #T_1c5b3_row1_col0, #T_1c5b3_row1_col1, #T_1c5b3_row1_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1c5b3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Title2</th>
#       <th id="T_1c5b3_level0_col0" class="col_heading level0 col0" >Master</th>
#       <th id="T_1c5b3_level0_col1" class="col_heading level0 col1" >Miss</th>
#       <th id="T_1c5b3_level0_col2" class="col_heading level0 col2" >Mr</th>
#       <th id="T_1c5b3_level0_col3" class="col_heading level0 col3" >Mrs</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c5b3_level0_row0" class="row_heading level0 row0" >0.000000</th>
#       <td id="T_1c5b3_row0_col0" class="data row0 col0" >17</td>
#       <td id="T_1c5b3_row0_col1" class="data row0 col1" >55</td>
#       <td id="T_1c5b3_row0_col2" class="data row0 col2" >451</td>
#       <td id="T_1c5b3_row0_col3" class="data row0 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_1c5b3_level0_row1" class="row_heading level0 row1" >1.000000</th>
#       <td id="T_1c5b3_row1_col0" class="data row1 col0" >23</td>
#       <td id="T_1c5b3_row1_col1" class="data row1 col1" >130</td>
#       <td id="T_1c5b3_row1_col2" class="data row1 col2" >87</td>
#       <td id="T_1c5b3_row1_col3" class="data row1 col3" >102</td>
#     </tr>
#   </tbody>
# </table>

# %%
list(data.groupby(['Title2', 'Pclass'])['Age'].mean().items())[:3]
# Out:
# [(('Master', 1), 6.984),
#  (('Master', 2), 2.7572727272727273),
#  (('Master', 3), 6.090000000000001)]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 153.5+ KB

# %%
data['Ticket_info'] = data['Ticket'].apply(lambda x : x.replace(".","").replace("/","").strip().split(' ')[0] if not x.isdigit() else 'X')


data['Ticket_info'].unique()
# Out:
# array(['A5', 'PC', 'STONO2', 'X', 'PP', 'CA', 'SCParis', 'SCA4', 'A4',
#        'SP', 'SOC', 'WC', 'SOTONOQ', 'WEP', 'STONO', 'C', 'SCPARIS',
#        'SOP', 'Fa', 'LINE', 'FCC', 'SWPP', 'SCOW', 'PPP', 'SC', 'SCAH',
#        'AS', 'SOPP', 'FC', 'SOTONO2', 'CASOTON', 'SCA3', 'STONOQ', 'AQ4',
#        'A', 'LP', 'AQ3'], dtype=object)

# %%
sns.countplot(x='Ticket_info', hue='Survived', data=data)
# Out:
# <Axes: xlabel='Ticket_info', ylabel='count'>

# %%
data['Embarked'] = data['Embarked'].fillna('S')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
#  15  Ticket_info  1309 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.8+ KB

# %%
data['Fare'] = data['Fare'].fillna(data['Fare'].mean())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1309 non-null   object
#  12  Family_Size  1309 non-null   int64
#  13  Title1       1309 non-null   object
#  14  Title2       1309 non-null   object
#  15  Ticket_info  1309 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.8+ KB

# %%
data['Cabin'].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
data["Cabin"] = data['Cabin'].apply(lambda x : str(x)[0] if not pd.isnull(x) else 'NoCabin')
data["Cabin"].unique()
# Out:
# array(['NoCabin', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
#sns.countplot(data['Cabin'], hue=data['Survived'])
sns.countplot(x='Cabin', hue='Survived', data=data)
# Out:
# <Axes: xlabel='Cabin', ylabel='count'>

# %%
data['Sex'] = data['Sex'].astype('category').cat.codes
data['Embarked'] = data['Embarked'].astype('category').cat.codes
data['Pclass'] = data['Pclass'].astype('category').cat.codes
data['Title1'] = data['Title1'].astype('category').cat.codes
data['Title2'] = data['Title2'].astype('category').cat.codes
data['Cabin'] = data['Cabin'].astype('category').cat.codes
data['Ticket_info'] = data['Ticket_info'].astype('category').cat.codes

# %%
dataAgeNull = data[data["Age"].isnull()]
dataAgeNotNull = data[data["Age"].notnull()]
remove_outlier = dataAgeNotNull[(np.abs(dataAgeNotNull["Fare"]-dataAgeNotNull["Fare"].mean())>(4*dataAgeNotNull["Fare"].std()))|
                      (np.abs(dataAgeNotNull["Family_Size"]-dataAgeNotNull["Family_Size"].mean())>(4*dataAgeNotNull["Family_Size"].std()))                     
                     ]
rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)
ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title1', 'Title2','Cabin','Ticket_info']
rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])

ageNullValues = rfModel_age.predict(X= dataAgeNull[ageColumns])
dataAgeNull.loc[:,"Age"] = ageNullValues
#data = dataAgeNull.append(dataAgeNotNull)
data = pd.concat([dataAgeNull, dataAgeNotNull])

data.reset_index(inplace=True, drop=True)

# %%
dataTrain = data[pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])
dataTest = data[~pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])

dataTrain.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Family_Size', 'Title1',
#        'Title2', 'Ticket_info'],
#       dtype='object')

# %%
dataTrain = dataTrain[['Survived', 'Age', 'Embarked', 'Fare',  'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]
dataTest = dataTest[['Age', 'Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]

dataTrain
# Out:
#      Survived        Age  Embarked     Fare  Pclass  Sex  Family_Size  Title2  \
# 263       0.0  22.000000         2   7.2500       2    1            1       2
# 264       1.0  38.000000         0  71.2833       0    0            1       3
# 265       1.0  26.000000         2   7.9250       2    0            0       1
# 266       1.0  35.000000         2  53.1000       0    0            1       3
# 267       0.0  35.000000         2   8.0500       2    1            0       2
# ..        ...        ...       ...      ...     ...  ...          ...     ...
# 973       0.0  27.000000         2  13.0000       1    1            0       2
# 974       1.0  19.000000         2  30.0000       0    0            0       1
# 176       0.0  19.099409         2  23.4500       2    0            3       1
# 975       1.0  26.000000         0  30.0000       0    1            0       2
# 976       0.0  32.000000         1   7.7500       2    1            0       2
#
#      Ticket_info  Cabin
# 263            2      7
# 264           14      2
# 265           31      7
# 266           36      2
# 267           36      7
# ..           ...    ...
# 973           36      7
# 974           36      1
# 176           34      7
# 975           36      2
# 976           36      7
#
# [891 rows x 10 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
 
rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=1000,
                             min_samples_split=12,
                             min_samples_leaf=1,
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1) 

rf.fit(dataTrain.iloc[:, 1:], dataTrain.iloc[:, 0])
print("%.4f" % rf.oob_score_)
# Out:
# 0.8294

# %%
pd.concat((pd.DataFrame(dataTrain.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(rf.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]
# Out:
#       variable  importance
# 4          Sex    0.264997
# 2         Fare    0.163890
# 6       Title2    0.152698
# 0          Age    0.131891
# 3       Pclass    0.091048
# 5  Family_Size    0.070839
# 8        Cabin    0.067029
# 7  Ticket_info    0.031735
# 1     Embarked    0.025873

# %%
rf_res =  rf.predict(dataTest)
submit['Survived'] = rf_res
submit['Survived'] = submit['Survived'].astype(int)
submit.to_csv('submit.csv', index= False)

# %%
submit

https://yulongtsai.medium.com/https-medium-com-yulongtsai-titanic-top3-8e64741cc11f
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
